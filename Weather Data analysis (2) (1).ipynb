# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
wd = pd.read_csv("C:\\Users\\Sayali\\Downloads\\Weather Data.csv")
wd
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
wd.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
wd.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
wd.shape
# Out:
# (8784, 8)

# %%
wd.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
column = wd.columns
for columns in column:
    print("->",columns)
# Out:
# -> Date/Time
# -> Temp_C
# -> Dew Point Temp_C
# -> Rel Hum_%
# -> Wind Speed_km/h
# -> Visibility_km
# -> Press_kPa
# -> Weather

# %%
wd.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
#unique_values

weather= wd['Weather'].unique()
for weathers in weather:
    print("->",weathers)
# Out:
# -> Fog
# -> Freezing Drizzle,Fog
# -> Mostly Cloudy
# -> Cloudy
# -> Rain
# -> Rain Showers
# -> Mainly Clear
# -> Snow Showers
# -> Snow
# -> Clear
# -> Freezing Rain,Fog
# -> Freezing Rain
# -> Freezing Drizzle
# -> Rain,Snow
# -> Moderate Snow
# -> Freezing Drizzle,Snow
# -> Freezing Rain,Snow Grains
# -> Snow,Blowing Snow
# -> Freezing Fog
# -> Haze
# -> Rain,Fog
# -> Drizzle,Fog
# -> Drizzle
# -> Freezing Drizzle,Haze
# -> Freezing Rain,Haze
# -> Snow,Haze
# -> Snow,Fog
# -> Snow,Ice Pellets
# -> Rain,Haze
# -> Thunderstorms,Rain
# -> Thunderstorms,Rain Showers
# -> Thunderstorms,Heavy Rain Showers
# -> Thunderstorms,Rain Showers,Fog
# -> Thunderstorms
# -> Thunderstorms,Rain,Fog
# -> Thunderstorms,Moderate Rain Showers,Fog
# -> Rain Showers,Fog
# -> Rain Showers,Snow Showers
# -> Snow Pellets
# -> Rain,Snow,Fog
# -> Moderate Rain,Fog
# -> Freezing Rain,Ice Pellets,Fog
# -> Drizzle,Ice Pellets,Fog
# -> Drizzle,Snow
# -> Rain,Ice Pellets
# -> Drizzle,Snow,Fog
# ...

# %%
#number of unique values
wd.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
#count number of values
# not count null values
wd.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
wd['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#find unique number of wind speeds
wd.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
# Renaming columns for consistency
wd.rename(columns={'Rel Hum_%': 'Humidity', 'Weather': 'Weather_condition'}, inplace=True)

# %%
# Data Exploration
print("\nNumber of unique values in each column:")
print(wd.nunique())
print("\nUnique weather conditions:")
print(wd['Weather_condition'].unique())
# Out:
# Number of unique values in each column:
# Date/Time            8784
# Temp_C                533
# Dew Point Temp_C      489
# Humidity               83
# Wind Speed_km/h        34
# Visibility_km          24
# Press_kPa             518
# Weather_condition      50
# dtype: int64
#
# Unique weather conditions:
# ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
# ...

# %%
# Check for missing values in each column
missing_values_per_column = wd.isnull().sum()

# Check if there are any missing values in the entire DataFrame
any_missing_values = wd.isnull().any().any()

# Print the results
print("Missing values per column:")
print(missing_values_per_column)

print("\nAre there any missing values in the DataFrame? ", any_missing_values)
# Out:
# Missing values per column:
# Date/Time            0
# Temp_C               0
# Dew Point Temp_C     0
# Humidity             0
# Wind Speed_km/h      0
# Visibility_km        0
# Press_kPa            0
# Weather_condition    0
# dtype: int64
#
# Are there any missing values in the DataFrame?  False

# %%
# Data Exploration
print("\nNumber of unique values in each column:")
print(wd.nunique())
print("\nUnique weather conditions:")
print(wd['Weather_condition'].unique())
# Out:
# Number of unique values in each column:
# Date/Time            8784
# Temp_C                533
# Dew Point Temp_C      489
# Humidity               83
# Wind Speed_km/h        34
# Visibility_km          24
# Press_kPa             518
# Weather_condition      50
# dtype: int64
#
# Unique weather conditions:
# ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
# ...

# %%
# Show all records where weather condition is 'Clear'
print("\nRecords where Weather Condition is Clear:")
print(wd[wd['Weather_condition'] == 'Clear'])
# Out:
# Records where Weather Condition is Clear:
#              Date/Time  Temp_C  Dew Point Temp_C  Humidity  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8        50               24
# 114   01-05-2012 18:00    -7.1             -14.4        56               11
# 115   01-05-2012 19:00    -9.2             -15.4        61                7
# 116   01-05-2012 20:00    -9.8             -15.7        62                9
# 117   01-05-2012 21:00    -9.0             -14.8        63               13
# ...                ...     ...               ...       ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8        89                4
# 8698  12/28/2012 10:00    -6.1              -8.6        82               19
# 8713   12/29/2012 1:00   -11.9             -13.6        87               11
# 8714   12/29/2012 2:00   -11.8             -13.1        90               13
# 8756  12/30/2012 20:00   -13.8             -16.5        80               24
#
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(wd['Humidity'], bins=20, color='green', alpha=0.7)
plt.xlabel('Humidity')
plt.ylabel('Frequency')
plt.title('Humidity Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Temp_C', y='Dew Point Temp_C', data=wd, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Dew Point Temperature (°C)')
plt.title('Temperature vs. Dew Point Temperature')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=wd['Wind Speed_km/h'], color='orange')
plt.xlabel('Wind Speed (km/h)')
plt.title('Wind Speed Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather_condition', data=wd, palette='viridis')
plt.xlabel('Weather Condition')
plt.ylabel('Count')
plt.title('Weather Condition Counts')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Plot a histogram of wind speeds
plt.figure(figsize=(10, 6))
sns.histplot(wd['Wind Speed_km/h'], bins=20, color='skyblue', kde=True)
plt.title('Distribution of Wind Speeds')
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Sayali\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(data=wd, x='Date/Time', y='Temp_C')
plt.title('Temperature Variation Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (Celsius)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sayali\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sayali\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
